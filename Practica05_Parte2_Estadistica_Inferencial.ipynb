# %% [markdown]
# ### **Parte 2: Limpieza de Datos**
#
# 1. Crear una columna de índice para poder identificar los registros.
#
# ```
# df["indice"] = range(1, len(df) + 1)
# ```
#
# 2. Realizar una limpieza de datos para todas las columnas del dataset.
#
# Asegurate de guardar en una variable distinta el dataset original, en caso de que debas recurrir a él nuevamente.

# %% [markdown]
# ### **Parte 3: Retomamos la Estadística Inferencial**
#
# 1. Obtener una muestra aleatoria de 1000 registros a partir del dataset crudo. Luego, filtrar esos mismos registros del dataset limpio de la siguiente manera:
#
# ```
# df_muestra_limpio = df_limpio.sample(1000, random_state=42)
#
# index_muestra = df_muestra_limpio["indice"].to_list()
#
# df_muestra_crudo = df_crudo[df_crudo["indice"].isin(index_muestra)]
# ```
#
# 2.  Calcular el intervalo de confianza para la media muestral del dataset **crudo** con un nivel de confianza de 0,05, utilizando el desvío muestral.
#
# 3. Calcular el intervalo de confianza para la media muestral del dataset **limpio** con un nivel de confianza de 0,05, utilizando el desvío muestral.
#
# 4. Comparar los resultados.
